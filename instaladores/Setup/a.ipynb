# %%
import pandas as pd

# %%
pd.read_csv('/Users/ctalamilla/Desktop/DH_DataScience/instaladores/Setup/encuesta_inicial (1).csv', sep=';')
# Out:
#       Nombre del Cuestionario       Apellido y Nombre del Alumno  \
# 0   DSAD - Encuesta de inicio                 Macarena Lovagnini
# 1   DSAD - Encuesta de inicio               Lucas Alberto Larese
# 2   DSAD - Encuesta de inicio                     Beatriz Dávila
# 3   DSAD - Encuesta de inicio                     Matilde Colman
# 4   DSAD - Encuesta de inicio                    Juan Cruz Cucci
# 5   DSAD - Encuesta de inicio                        Isaac Lopez
# 6   DSAD - Encuesta de inicio  Gabriela Beatriz Mattioli Montaña
# 7   DSAD - Encuesta de inicio                      Matias Pagano
# 8   DSAD - Encuesta de inicio            Patricia Viviana Serini
# 9   DSAD - Encuesta de inicio                      Diego Fonseca
# 10  DSAD - Encuesta de inicio             Leandro Hernan Vazquez
# 11  DSAD - Encuesta de inicio                    Gustavo Delmont
# 12  DSAD - Encuesta de inicio            Tomas Alejandro Duhalde
# ...
